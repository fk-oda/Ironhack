# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##About:
#     Our goal for the analysis of the dataset was focused on identifying the statistics related to the reported attack's country, date, name of the victim and if the incident was fatal.

# %%
st = 'Fatal (Y/N)'
s2 = 'test'

# %%
a = st.split(' ')
a
# Out:
# ['Fatal', '(Y/N)']

# %%
df = pd.read_csv('./data/attacks.csv', encoding='ansi')
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df_cleaned = df.drop(df[df.loc[:,:].isnull().all(1)].index)
df_cleaned = df_cleaned.drop(df_cleaned[df_cleaned.iloc[:,1:].isnull().all(1)].index)
df_cleaned = df_cleaned.drop(df_cleaned[df_cleaned.iloc[:,1:19].isnull().all(1)].index)
df_cleaned[['Unnamed: 22','Unnamed: 23']].isnull()
# Out:
#       Unnamed: 22  Unnamed: 23
# 0            True         True
# 1            True         True
# 2            True         True
# 3            True         True
# 4            True         True
# ...           ...          ...
# 6297         True         True
# 6298         True         True
# 6299         True         True
# 6300         True         True
# 6301         True         True
#
# [6302 rows x 2 columns]

# %%
len(df_cleaned['Country'].unique())
# Out:
# 213

# %%
pd.options.display.max_colwidth = 240
df_cleaned = df_cleaned.loc[:,'Date']
# Out:
#                                                                      href formula  \
# 50   http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf
# 96  http://sharkattackfile.net/spreadsheets/pdf_directory/2017.08.27-Brundler.pdf
#
#                                                                                                                                    href
# 50   http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2018.01.13-Stewart.pdf
# 96  http://sharkattackfile.net/spreadsheets/pdf_directory/http://sharkattackfile.net/spreadsheets/pdf_directory/2017.08.27-Brundler.pdf
